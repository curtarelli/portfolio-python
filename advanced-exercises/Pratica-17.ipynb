# %%
# Importando bibliotecas/pacotes utilizados
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

mpl.__version__
# Out:
# '2.2.2'

# %%
# Verificando versões correntes
# !python --version
# !jupyter --version
# !jupyter notebook --version
# Out:
# Python 3.6.4 :: Anaconda, Inc.
# 4.4.0
# 5.4.1

# %%
# Obtendo informação sobre um pacote, pode-se usat tbm SHIFT+TAB (até 3 vezes)
plt.plot?

# %%
#Exemplo de plot em branco
plt.plot()
# Out:
# []

# %%
# Dados eixo X [Anos - T]
ano = [2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017]

# Dados eixo Y [Focos de incencido - N]
num_focos = [123, 123, 249, 133, 194, 115, 183, 236, 188, 260]

# %%
# Plotando dados em linhas
plt.plot(ano, num_focos)

# %%
# Correção do cabeçalho com uso de ';'
plt.plot(ano, num_focos);

# %%
# Adicionando título e rótulos de eixos
plt.plot(ano, num_focos)

plt.xlabel('Ano', fontsize=16)
plt.ylabel('Número de focos (em milhares)')

plt.title('Focos de Queimada - Brasil', fontsize=24);

# %%
# Controlando a plotagem como figura
plt.figure(figsize=(10, 5))

plt.plot(ano, num_focos)

plt.xlabel('Ano', fontsize=16)
plt.ylabel('Número de focos (em milhares)')

plt.title('Focos de Queimada - Brasil', fontsize=24);

# %%
# Controlando a plotagem como figura
plt.figure(figsize=plt.figaspect(0.5))

plt.plot(ano, num_focos)

plt.xlabel('Ano', fontsize=16)
plt.ylabel('Número de focos (em milhares)')

plt.title('Focos de Queimada - Brasil', fontsize=24);

# %%
# Controlando eixos
plt.plot(ano, num_focos)

plt.xlabel('Ano', fontsize=16)
plt.ylabel('Número de focos (em milhares)')

plt.title('Focos de Queimada - Brasil', fontsize=24)

plt.yticks([100, 140, 180, 220, 260]);

# %%
# Controlando eixos aprimorado
plt.plot(ano, num_focos)

plt.xlabel('Ano', fontsize=16)
plt.ylabel('Número de focos (em milhares)')

plt.title('Focos de Queimada - Brasil', fontsize=24)

plt.yticks([100, 140, 180, 220, 260],['100 mil', '140 mil', '180 mil', '220 mil', '260 mil']);

# %%
# Controlando formatação da linha
plt.plot(ano, num_focos, 'ro-', linewidth=2.0)

plt.xlabel('Ano', fontsize=16)
plt.ylabel('Número de focos (em milhares)')

plt.title('Focos de Queimada - Brasil', fontsize=24)

plt.yticks([100, 140, 180, 220, 260],
           ['100 mil', '140 mil', '180 mil', '220 mil', '260 mil']);

# %%
# Controlando formatação da linha aprimorado
plt.figure(figsize=(10, 8))

plt.plot(ano, num_focos,
        color='red', linestyle='dashed', linewidth=3,
        marker='s', markersize=20,
         mew=5, mec='blue', mfc='lightblue')

plt.xlabel('Ano', fontsize=16)
plt.ylabel('Número de focos (em milhares)')

plt.title('Focos de Queimada - Brasil', fontsize=24)

plt.yticks([100, 140, 180, 220, 260],
           ['100 mil', '140 mil', '180 mil', '220 mil', '260 mil']);

# %%
# Usando o matplotlib e numpy
t = np.linspace(0.0, 2.0, 100)

f = np.sin(np.pi * t)

plt.figure(figsize=(10, 8))

plt.plot(t,f, 'orange', linewidth=2.0)

plt.xlim([0.0, 2.0])
plt.ylim([-1.0, 1.0])

plt.xlabel(r'$t$', fontsize=16)
plt.ylabel(r'$f(t)$', fontsize=16)

plt.title(r'$f(t)=sin(\pi \times t)$', fontsize=24)

plt.grid(b=True, color='gray', linestyle='--', linewidth=0.5);

# %%
# Vários gráficos em uma mesma área 1
t = np.linspace(0.0, 2.0, 100)

f1 = np.sin(np.pi * t)
f2 = np.sin(np.pi * 2 * t)

plt.figure(figsize=(10, 8))

plt.plot(t, f1, 'orange', linewidth=2.0,
        label=r'$f_1(t)=sin(\pi \times t)$')

plt.plot(t, f2, 'purple', linewidth=2.0,
        label=r'$f_2(t)=sin(2 \times \pi \times t)$')

plt.xlim([0.0, 2.0])
plt.ylim([-1.0, 1.0])

plt.xlabel(r'$t$', fontsize=16)
plt.ylabel(r'$f(t)$', fontsize=16)

plt.title('Senóides', fontsize=24)

plt.legend()

plt.grid(b=True, color='gray', linestyle='--', linewidth=0.5);

# %%
# Vários gráficos em uma mesma área 2
t = np.linspace(0.0, 2.0, 100)

f1 = np.sin(np.pi * t)
f2 = np.sin(np.pi * 2 * t)

plt.figure(figsize=(10, 8))

plt.plot(t, f1, 'orange',
         t, f2, 'purple',
         linewidth=2.0)

plt.xlim([0.0, 2.0])
plt.ylim([-1.0, 1.0])

plt.xlabel(r'$t$', fontsize=16)
plt.ylabel(r'$f(t)$', fontsize=16)

plt.title('Senóides', fontsize=24)

plt.legend([r'$f_1(t)=sin(\pi \times t)$',
           r'$f_2(t)=sin(2 \times \pi \times t)$'])

plt.grid(b=True, color='gray', linestyle='--', linewidth=0.5);

# %%
# Vários gráficos em uma mesma figura, multiplas áreas de desenho
t = np.linspace(0.0, 2.0, 100)

f1 = np.sin(np.pi * t)
f2 = np.sin(np.pi * 2 * t)
f3 = np.sin(np.pi * 4 * t)
f4 = np.sin(np.pi * 8 * t)

plt.figure(figsize=(10, 8))

plt.subplot(221, facecolor='#FFFFEA')
plt.plot(t, f1, 'orange')
plt.title(r'$f_1(t)=sin(\pi \times t)$')

plt.subplot(222)
plt.plot(t, f2, 'purple')
plt.title(r'$f_2(t)=sin(2 \times \pi \times t)$')

plt.subplot(223)
plt.plot(t, f3, 'salmon')
plt.title(r'$f_2(t)=sin(4 \times \pi \times t)$')

plt.subplot(224, facecolor='#FEEEEE')
plt.plot(t, f4, 'crimson')
plt.title(r'$f_2(t)=sin(8 \times \pi \times t)$')

plt.suptitle('Senóides', fontsize=24);

# %%
# Gráficos de barras
x_pos = [x for x in range(len(ano))]

plt.figure(figsize=(10, 8))

plt.bar(x_pos, num_focos, align='center',
       color='crimson', linewidth=2, edgecolor='black')

plt.yticks([0, 75, 150, 225, 300],
          ['0', '75 mil', '150 mil', '225 mil', '300 mil'])

plt.xticks(x_pos, ano, rotation=45)

plt.title('Focos de Queimadas - Brasil')

plt.xlabel('Ano')
plt.ylabel('Número de focos detectados')

plt.grid(b=True, color='gray', linestyle='--', linewidth=0.5);

# %%
# Definindo dados para scatter plot
ano2 = [1900, 1920, 1940, 1960, 1970, 1980, 1990, 2000, 2010]

pop = [17.438, 30.635, 41.236, 51.944, 70.992, 121.150, 146.917, 169.590, 190.755]

# %%
# Scatter plot simples
plt.scatter(ano2, pop);

# %%
# Scatterplot formatação 1
plt.figure(figsize=(10, 8) )

plt.scatter(ano2, pop)

plt.xlabel("Ano")
plt.ylabel("Estimativa da População")

plt.title("Evolução da População Brasileira")

plt.yticks([50, 100, 150, 200],
           ['50M', '100M', '150M', '200M' ] );

plt.grid(b=True, color='gray', linestyle='--', linewidth=0.5);

# %%
# Scatterplot formatação 2
plt.figure(figsize=(10, 8) )

plt.scatter(ano2, pop, marker="s", s=50, c="darkorange")

plt.xlabel("Ano")
plt.ylabel("Estimativa da População")

plt.title("Evolução da População Brasileira")

plt.yticks([50, 100, 150, 200],
           ['50M', '100M', '150M', '200M'] );

# %%
# Scatterplot formatação 3
plt.figure(figsize=(10, 8) )

cores = ("#fff5eb", "#fee6ce", "#fdd0a2", "#fdae6b", "#fd8d3c", "#f16913", "#d94801", "#a63603", "#7f2704")

plt.scatter(ano2, pop, marker="s", s=50, c=cores)

plt.xlabel("Ano")
plt.ylabel("Estimativa da População")

plt.title("Evolução da População Brasileira")

plt.yticks([50, 100, 150, 200],
           ['50M', '100M', '150M', '200M']);

# %%
# Scatterplot formatação 4
cores = ("#fff5eb", "#fee6ce", "#fdd0a2", "#fdae6b", "#fd8d3c", "#f16913", "#d94801", "#a63603", "#7f2704")

tamanhos = (10, 20, 30, 40, 80, 160, 300, 400, 500)

plt.figure(figsize=(10, 8) )

plt.scatter(ano2, pop, marker="o", s=tamanhos, c=cores)

plt.xlabel("Ano")
plt.ylabel("Estimativa da População")

plt.title("Evolução da População Brasileira")

plt.yticks([ 50, 100, 150, 200 ],
           [ '50M', '100M', '150M', '200M' ] );

# %%
# Scatterplot formatação 5
import matplotlib.cm as cm

cores = [ x for x in range( len( ano2 ) ) ]

plt.figure( figsize=(10, 8) )

plt.scatter(ano2, pop, marker="s", s=50, c=cores, cmap="rainbow")

plt.xlabel("Ano")
plt.ylabel("Estimativa da População")

plt.title("Evolução da População Brasileira");

plt.yticks([ 50, 100, 150, 200 ],
           [ '50M', '100M', '150M', '200M' ] )

plt.show()

# %%
# Scatter plot para N valores com coordenadas x e y e peso (áreas), onde o peso define o tamanho da figura no gráfico 
N = 80

# vamos sortear N valores no intervalo [0, 1) para cada eixo.
x = np.random.rand(N)
y = np.random.rand(N)

# vamos sortear N valores no intervalo [0, 1) para associar a cores.
colors = np.random.rand(N)

# cada elemento será um círculo de raio entre 0 e 20 pontos.
area = np.pi * (20 * np.random.rand(N))**2

plt.figure( figsize=(10, 8) )

plt.scatter(x, y, s=area, c=colors, alpha=0.5);

# %%
# Histograma simples
μ = 200
σ = 25

values = np.random.normal(μ, σ, size=100)

plt.figure( figsize=(8, 8) )

plt.hist(values, bins=10, density=False, align='left',
         facecolor='green', edgecolor='black', linewidth=1.2, alpha=0.65);

plt.title(r"Distribuição Normal: $\mu=200$ e $\sigma=25$")

plt.xlabel("Valor")
plt.ylabel("Frequência");

# %%
# Histograma com curva de distribuição normal
μ = 200
σ = 25

values = np.random.normal(μ, σ, size = 100)

plt.figure( figsize=(15, 5) )

count, bins, ignored = plt.hist(values, bins=30, density=True,
                                align='left', facecolor='lightblue',
                                edgecolor='black', linewidth=1.2,
                                alpha=0.65);

plt.title(r"Distribuição Normal: $\mu=200$ e $\sigma=25$")

plt.xlabel("Valor")
plt.ylabel("Frequência")

plt.plot( bins, 1 / ( σ * np.sqrt(2 * np.pi) ) *
                np.exp( - (bins - μ)**2 / (2 * σ**2) ),
          linewidth=1.5, color='r' );

# %%
# Backend padrão em acesso à imagem
# %matplotlib inline
import matplotlib.pyplot as plt

ano = [ 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017 ]

num_focos = [ 123, 123, 249, 133, 194, 115, 183, 236, 188, 260 ]

plt.plot(ano, num_focos);

# %%
# Backend com acesso à imagem
# %matplotlib nbagg
import matplotlib.pyplot as plt

ano = [ 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017 ]

num_focos = [ 123, 123, 249, 133, 194, 115, 183, 236, 188, 260 ]

plt.plot(ano, num_focos);

# %%
# Backend plot em janela separada
# %matplotlib qt
import matplotlib.pyplot as plt

ano = [ 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017 ]

num_focos = [ 123, 123, 249, 133, 194, 115, 183, 236, 188, 260 ]

plt.plot(ano, num_focos);

# %%
# Backend plot em janela separada
# %matplotlib  tk
import matplotlib.pyplot as plt

ano = [ 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017 ]

num_focos = [ 123, 123, 249, 133, 194, 115, 183, 236, 188, 260 ]

plt.plot(ano, num_focos);

# %%
# Tipos de Backend
# %matplotlib --list

# %%
# Outra forma de designar o Backend
import matplotlib as mpl
mpl.use('nbAgg')
import matplotlib.pyplot as plt

ano = [ 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017 ]

num_focos = [ 123, 123, 249, 133, 194, 115, 183, 236, 188, 260 ]

plt.plot(ano, num_focos);

# %% [markdown]
# # Exercícios:

# %%
# Definindo listas de dados para os exercícios
faixa_etaria = ['0 a 4 anos', '5 a 9 anos', '10 a 14 anos', '15 a 19 anos', '20 a 24 anos', '25 a 29 anos',
                '30 a 34 anos', '35 a 39 anos', '40 a 44 anos', '45 a 49 anos', '50 a 54 anos', '55 a 59 anos',
                '60 a 64 anos', '65 a 69 anos', '70 a 74 anos', '75 a 79 anos', '80 a 84 anos', '85 a 89 anos',
                '90 a 94 anos', '95 a 99 anos', '100 anos e mais']
masculino = [7016987, 7624144, 8725413, 8558868, 8630229, 8460995, 7717658, 6766664, 6320568, 5692014, 4834995, 3902344, 3041035,
            2224065, 1667372, 1090517, 668623, 310759, 114964, 31592, 7247]
feminino = [6779171, 7345231, 8441348, 8432004, 8614963, 8643419, 8026854, 7121915, 6688796, 6141338, 5305407, 4373877, 3468085,
           2616745, 2074264, 1472930, 998349, 508724, 211594, 66806, 16989]

# %% [markdown]
# ## Exercício 1

# %%
# Gráfico de colunas para os dados da população feminina
x_pos = [x for x in range(len(faixa_etaria))]

plt.figure(figsize=(8, 12))

plt.bar(x_pos, feminino, align='center',
       color='crimson', linewidth=2, edgecolor='black')

plt.yticks([0, 100000, 500000, 1000000, 2000000, 3000000, 4000000, 5000000, 6000000, 7000000, 8000000, 9000000],
          ['0', '0,1 mi', '0,5 mi', '1 mi', '2 mi', '3 mi', '4 mi', '5 mi', '6 mi', '7 mi', '8 mi', '9 mi'])

plt.xticks(x_pos, faixa_etaria, rotation=45)

plt.title('População Feminina por Faixa Etária')

plt.xlabel('Faixa etária')
plt.ylabel('População')

plt.grid(b=True, color='gray', linestyle='--', linewidth=0.5);

# %% [markdown]
# ## Exercício 2

# %%
# Gráfico de colunas para os dados da população feminina
x_pos = [x for x in range(len(faixa_etaria))]

plt.figure(figsize=(18, 10))

plt.barh(x_pos, masculino, align='center',
       color='blue', linewidth=2, edgecolor='black')

plt.xticks([0, 500000, 1000000, 2000000, 3000000, 4000000, 5000000, 6000000, 7000000, 8000000, 9000000],
          ['0', '0,5 mi', '1 mi', '2 mi', '3 mi', '4 mi', '5 mi', '6 mi', '7 mi', '8 mi', '9 mi'])

plt.yticks(x_pos, faixa_etaria, rotation=45)

plt.title('População Masculina por Faixa Etária')

plt.xlabel('População')
plt.ylabel('Faixa etária')

plt.grid(b=True, color='gray', linestyle='--', linewidth=0.5);

# %% [markdown]
# ## Exercício 3

# %%
# Vários gráficos em uma mesma figura, multiplas áreas de desenho
x_pos = [x for x in range(len(faixa_etaria))]

plt.figure(figsize=(20, 8))

plt.subplot(121)
plt.barh(x_pos, masculino, align='center',
       color='blue', linewidth=2, edgecolor='black')

plt.xlim(9000000, 0)

plt.xticks([0, 1000000, 2000000, 3000000, 4000000, 5000000, 6000000, 7000000, 8000000, 9000000],
          ['0', '1 mi', '2 mi', '3 mi', '4 mi', '5 mi', '6 mi', '7 mi', '8 mi', '9 mi'])

plt.title('Pop. Masculina')

plt.xlabel('População')

plt.grid(b=True, color='gray', linestyle='--', linewidth=0.5);

plt.subplot(122)
plt.barh(x_pos, feminino, align='center',
       color='red', linewidth=2, edgecolor='black')

plt.xticks([0, 1000000, 2000000, 3000000, 4000000, 5000000, 6000000, 7000000, 8000000, 9000000],
          ['0', '1 mi', '2 mi', '3 mi', '4 mi', '5 mi', '6 mi', '7 mi', '8 mi', '9 mi'])

plt.yticks(x_pos, faixa_etaria)

plt.title('Pop. Feminina')

plt.xlabel('População')

plt.grid(b=True, color='gray', linestyle='--', linewidth=0.5);


plt.suptitle('População por Faixa Etária', fontsize=24);
