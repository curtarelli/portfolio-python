# %% [markdown]
# # Example of application of the band array script

# %%
## Importing the functions
from core.band_array_application import *

# %%
# Apliyng the function:
# %matplotlib inline
random_matrix_sum(8, 50, 50);
# Out:
# Band 1 [50x50 - 8-bits]:
#
#  [[ 45  71 168 ... 153  72 148]
#  [ 70  84   3 ... 221 130   8]
#  [182  27 206 ... 159  15 201]
#  ...
#  [152 124 203 ... 228 199 108]
#  [248 194 202 ...  29  20 100]
#  [134  41 109 ...  48 119 108]]
#
# Band 2 [50x50 - 8-bits]:
#
#  [[198   5  61 ...  50  27 241]
#  [ 78 113 212 ...  30 148 118]
#  [ 84 166  71 ... 228 100 202]
#  ...
#  [ 82  42 170 ... 221 250 156]
#  [120 161  88 ...  23 216  29]
#  [ 55  12 229 ... 253  34  56]]
#
# Band 3 = Band 1 + Band 2 (corrected) [50x50 - 8-bits]:
#
#  [[243  76 229 ... 203  99 255]
#  [148 197 215 ... 251 255 126]
#  [255 193 255 ... 255 115 255]
#  ...
#  [234 166 255 ... 255 255 255]
#  [255 255 255 ...  52 236 129]
#  [189  53 255 ... 255 153 164]]

# %%
# Apliyng the function:
# %matplotlib qt5
random_matrix_sum(12, 100, 100)
# Out:
# ...
#
# Band 1 [100x100 - 12-bits]:
#
#  [[1832 1130 1254 ... 2740 1135 2707]
#  [ 890 3117 1906 ... 3266 3886 3887]
#  [3308  664 1428 ... 3911 1973 1450]
#  ...
#  [2150 1112 1408 ... 2608 3114 2660]
#  [1538  809 3564 ...  313  474  246]
#  [3537 3576 1637 ... 3340 3329 2502]]
#
# Band 2 [100x100 - 12-bits]:
#
#  [[3850 1192 2868 ... 3842 2075 3493]
#  [3162  784  109 ... 3184  599  561]
#  [3321  438 1200 ... 1209  742 2953]
#  ...
#  [1002  501 1717 ...  779 1159 1782]
#  [2787 3258  673 ...  569 1292 3130]
#  [ 544 2125 1606 ... 4095 4053 3990]]
#
# Band 3 = Band 1 + Band 2 (corrected) [100x100 - 12-bits]:
#
#  [[4095 2322 4095 ... 4095 3210 4095]
#  [4052 3901 2015 ... 4095 4095 4095]
#  [4095 1102 2628 ... 4095 2715 4095]
#  ...
#  [3152 1613 3125 ... 3387 4095 4095]
#  [4095 4067 4095 ...  882 1766 3376]
#  [4081 4095 3243 ... 4095 4095 4095]]

# %%
# Apliyng the function:
# %matplotlib qt5
random_matrix_sum(24, 50, 100);
# Out:
# ...
#
# Band 1 [50x100 - 24-bits]:
#
#  [[14916196  2641455 16543055 ... 15793864  3185194 15629539]
#  [ 6326679 12987869  9858937 ...  2555291 15874098  1620913]
#  [10205726  3740430  9032003 ... 14374907 12338240  6473438]
#  ...
#  [ 8938934 15682993    28041 ...   538761 13278615 11044538]
#  [10357549  6981946 11987120 ...   374688 11799278   280189]
#  [ 9680002  3787887 14789667 ...  1376730 15138516 13123639]]
#
# Band 2 [50x100 - 24-bits]:
#
#  [[ 9789896 14923272  9470184 ... 16515321 10871972 12416236]
#  [ 6948053 10032970  9338698 ... 10765945 11561284   165691]
#  [11473733  9576737  8080530 ...  3286502  6812703  8558598]
#  ...
#  [11655979 15114974  1890339 ...  2315670 12104612 12726291]
#  [  170849 15219606  5368924 ... 15088986  3131366  1157158]
#  [ 9564813 10658345  4543789 ...  2310297 13111822  1828477]]
#
# Band 3 = Band 1 + Band 2 (corrected) [50x100 - 24-bits]:
#
#  [[16777215 16777215 16777215 ... 16777215 14057166 16777215]
# ...
